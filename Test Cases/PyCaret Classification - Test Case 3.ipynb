# %%
from pycaret.datasets import get_data
data = get_data('glass')
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %%
from pycaret.classification import *

# %%
s = setup(data, target = 'Type')
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_8f11b3c0_37b6_11ea_95fb_84fdd13f47d7" ><thead>    <tr>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_8f11b3c0_37b6_11ea_95fb_84fdd13f47d7row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_8f11b3c0_37b6_11ea_95fb_84fdd13f47d7row0_col1" class="data row0 col1" >2732</td>
#             </tr>
#             <tr>
#                                 <td id="T_8f11b3c0_37b6_11ea_95fb_84fdd13f47d7row1_col0" class="data row1 col0" >Target Type</td>
#                         <td id="T_8f11b3c0_37b6_11ea_95fb_84fdd13f47d7row1_col1" class="data row1 col1" >Multiclass</td>
#             </tr>
#             <tr>
# ...

# %% [markdown]
# ## Compare Models

# %%
# %%time
compare_models()
# Out:
# Wall time: 53.1 s
# <style  type="text/css" >
#     #T_bbf0df02_37b6_11ea_986d_84fdd13f47d7 th {
#           text-align: left;
#     }    #T_bbf0df02_37b6_11ea_986d_84fdd13f47d7row0_col0 {
#             text-align:  left;
#         }    #T_bbf0df02_37b6_11ea_986d_84fdd13f47d7row0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_bbf0df02_37b6_11ea_986d_84fdd13f47d7row0_col2 {
#             text-align:  left;
#         }    #T_bbf0df02_37b6_11ea_986d_84fdd13f47d7row0_col3 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_bbf0df02_37b6_11ea_986d_84fdd13f47d7row0_col4 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_bbf0df02_37b6_11ea_986d_84fdd13f47d7row0_col5 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_bbf0df02_37b6_11ea_986d_84fdd13f47d7row0_col6 {
#             background-color:  yellow;
# ...

# %% [markdown]
# ## Create Model

# %%
gbc = create_model('gbc')
# Out:
#       Accuracy  AUC  Recall   Prec.      F1   Kappa
# 0       0.6471  0.0  0.5778  0.5686  0.6021  0.5256
# 1       0.6471  0.0  0.6278  0.7304  0.6608  0.5584
# 2       0.8750  0.0  0.8056  0.8229  0.8466  0.8261
# 3       0.8000  0.0  0.6333  0.7000  0.7430  0.7239
# 4       0.8000  0.0  0.5833  0.7159  0.7364  0.7134
# 5       0.8000  0.0  0.7167  0.7778  0.7697  0.7273
# 6       0.8571  0.0  0.9200  0.9048  0.8544  0.8056
# 7       0.6429  0.0  0.4200  0.5804  0.5842  0.4574
# 8       0.7857  0.0  0.6000  0.6241  0.6937  0.6769
# 9       0.8333  0.0  0.6250  0.7976  0.7917  0.7363
# Mean    0.7688  0.0  0.6509  0.7222  0.7283  0.6751
# SD      0.0848  0.0  0.1296  0.1030  0.0885  0.1155

# %%
catboost = create_model('catboost')
# Out:
#       Accuracy  AUC  Recall   Prec.      F1   Kappa
# 0       0.7059  0.0  0.6611  0.7333  0.7020  0.6119
# 1       0.8235  0.0  0.7778  0.7824  0.7947  0.7661
# 2       0.8750  0.0  0.8056  0.8229  0.8466  0.8261
# 3       0.7333  0.0  0.6000  0.6444  0.6824  0.6319
# 4       0.8667  0.0  0.7500  0.8222  0.8283  0.8137
# 5       0.8000  0.0  0.6333  0.7111  0.7475  0.7256
# 6       0.8571  0.0  0.9200  0.9048  0.8544  0.8056
# 7       0.6429  0.0  0.4200  0.5765  0.5877  0.4574
# 8       0.9286  0.0  0.8000  0.8690  0.8961  0.8971
# 9       0.8333  0.0  0.6250  0.7976  0.7917  0.7363
# Mean    0.8066  0.0  0.6993  0.7664  0.7731  0.7271
# SD      0.0831  0.0  0.1334  0.0961  0.0891  0.1221

# %%
lr = create_model('lr', ensemble=True, method='Bagging')
# Out:
#       Accuracy  AUC  Recall   Prec.      F1   Kappa
# 0       0.5882  0.0  0.5444  0.5000  0.5330  0.4439
# 1       0.4706  0.0  0.4944  0.3562  0.3798  0.2982
# 2       0.6250  0.0  0.5444  0.5521  0.5830  0.4754
# 3       0.4667  0.0  0.3333  0.3762  0.4037  0.2593
# 4       0.6000  0.0  0.3500  0.5222  0.5364  0.4118
# 5       0.7333  0.0  0.6000  0.6556  0.6869  0.6341
# 6       0.7143  0.0  0.6800  0.6845  0.6883  0.6000
# 7       0.5714  0.0  0.3800  0.5198  0.5091  0.3488
# 8       0.6429  0.0  0.6400  0.6071  0.6190  0.5000
# 9       0.5000  0.0  0.3300  0.5417  0.4963  0.2653
# Mean    0.5912  0.0  0.4897  0.5315  0.5436  0.4237
# SD      0.0883  0.0  0.1259  0.1006  0.0993  0.1257

# %%
svm = create_model('svm', ensemble=True, method='Bagging')
# Out:
#       Accuracy  AUC  Recall   Prec.      F1   Kappa
# 0       0.3529  0.0  0.1667  0.1246  0.1841  0.0000
# 1       0.4118  0.0  0.3333  0.1729  0.2426  0.2342
# 2       0.3750  0.0  0.1667  0.1406  0.2045  0.0000
# 3       0.3333  0.0  0.1667  0.1282  0.1852  0.0506
# 4       0.4000  0.0  0.2500  0.2524  0.2643  0.1176
# 5       0.4000  0.0  0.3000  0.2000  0.2667  0.1867
# 6       0.3571  0.0  0.2000  0.1276  0.1880  0.0000
# 7       0.4286  0.0  0.3000  0.3214  0.3333  0.2057
# 8       0.3571  0.0  0.2000  0.1276  0.1880  0.0000
# 9       0.3333  0.0  0.2500  0.1111  0.1667  0.0000
# Mean    0.3749  0.0  0.2333  0.1706  0.2223  0.0795
# SD      0.0317  0.0  0.0592  0.0651  0.0501  0.0923

# %%
et = create_model('et', ensemble=True, method='Boosting')
# Out:
#       Accuracy  AUC  Recall   Prec.      F1   Kappa
# 0       0.6471  0.0  0.6278  0.6549  0.6449  0.5405
# 1       0.7059  0.0  0.5833  0.6529  0.6717  0.6101
# 2       0.8750  0.0  0.9389  0.8750  0.8750  0.8298
# 3       0.7333  0.0  0.6000  0.6444  0.6824  0.6319
# 4       0.8000  0.0  0.7167  0.7778  0.7697  0.7273
# 5       0.8000  0.0  0.7167  0.7714  0.7667  0.7205
# 6       0.7857  0.0  0.8800  0.8571  0.7917  0.7162
# 7       0.7857  0.0  0.7200  0.7857  0.7544  0.7063
# 8       0.9286  0.0  0.8000  0.8690  0.8961  0.8971
# 9       0.7500  0.0  0.4600  0.8056  0.7481  0.6327
# Mean    0.7811  0.0  0.7043  0.7694  0.7601  0.7012
# SD      0.0763  0.0  0.1366  0.0853  0.0775  0.0999

# %% [markdown]
# ## Plot Model

# %%
plot_model(gbc)

# %%
plot_model(gbc, plot = 'error')

# %%
plot_model(gbc, plot = 'confusion_matrix')

# %%
plot_model(gbc, plot = 'boundary')

# %%
evaluate_model(et)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %% [markdown]
# ## Blend Models

# %%
b1 = blend_models()
# Out:
#       Accuracy  AUC  Recall   Prec.      F1   Kappa
# 0       0.7059  0.0  0.6056  0.6275  0.6610  0.6047
# 1       0.7059  0.0  0.6111  0.6222  0.6432  0.5933
# 2       0.8125  0.0  0.7778  0.7732  0.7831  0.7405
# 3       0.6667  0.0  0.5667  0.5960  0.6178  0.5399
# 4       0.8667  0.0  0.7500  0.8222  0.8283  0.8137
# 5       0.7333  0.0  0.5500  0.6714  0.6778  0.6273
# 6       0.8571  0.0  0.9200  0.9048  0.8544  0.8056
# 7       0.7143  0.0  0.4600  0.6446  0.6580  0.5659
# 8       0.9286  0.0  0.8000  0.8690  0.8961  0.8971
# 9       0.7500  0.0  0.4600  0.8056  0.7481  0.6327
# Mean    0.7741  0.0  0.6501  0.7336  0.7368  0.6821
# SD      0.0821  0.0  0.1464  0.1080  0.0939  0.1163

# %%
b9 = blend_models([gbc,gbc,gbc])
# Out:
#       Accuracy  AUC  Recall   Prec.      F1   Kappa
# 0       0.6471  0.0  0.5778  0.5686  0.6021  0.5256
# 1       0.6471  0.0  0.6278  0.7304  0.6608  0.5584
# 2       0.8750  0.0  0.8056  0.8229  0.8466  0.8261
# 3       0.8000  0.0  0.6333  0.7000  0.7430  0.7239
# 4       0.8000  0.0  0.5833  0.7159  0.7364  0.7134
# 5       0.8000  0.0  0.7167  0.7778  0.7697  0.7273
# 6       0.8571  0.0  0.9200  0.9048  0.8544  0.8056
# 7       0.6429  0.0  0.4200  0.5804  0.5842  0.4574
# 8       0.7857  0.0  0.6000  0.6241  0.6937  0.6769
# 9       0.8333  0.0  0.6250  0.7976  0.7917  0.7363
# Mean    0.7688  0.0  0.6509  0.7222  0.7283  0.6751
# SD      0.0848  0.0  0.1296  0.1030  0.0885  0.1155
