# %%
from pycaret.datasets import get_data
data = get_data('bike')
# Out:
#    season  yr  mnth  hr  holiday  weekday  workingday  weathersit  temp  \
# 0       1   0     1   0        0        6           0           1  0.24
# 1       1   0     1   1        0        6           0           1  0.22
# 2       1   0     1   2        0        6           0           1  0.22
# 3       1   0     1   3        0        6           0           1  0.24
# 4       1   0     1   4        0        6           0           1  0.24
#
#     atemp   hum  windspeed  casual  registered  cnt
# 0  0.2879  0.81        0.0       3          13   16
# 1  0.2727  0.80        0.0       8          32   40
# 2  0.2727  0.80        0.0       5          27   32
# 3  0.2879  0.75        0.0       3          10   13
# 4  0.2879  0.75        0.0       0           1    1

# %%
data2 = get_data('bike')
data2 = data2.head(10000)
# Out:
#    season  yr  mnth  hr  holiday  weekday  workingday  weathersit  temp  \
# 0       1   0     1   0        0        6           0           1  0.24
# 1       1   0     1   1        0        6           0           1  0.22
# 2       1   0     1   2        0        6           0           1  0.22
# 3       1   0     1   3        0        6           0           1  0.24
# 4       1   0     1   4        0        6           0           1  0.24
#
#     atemp   hum  windspeed  casual  registered  cnt
# 0  0.2879  0.81        0.0       3          13   16
# 1  0.2727  0.80        0.0       8          32   40
# 2  0.2727  0.80        0.0       5          27   32
# 3  0.2879  0.75        0.0       3          10   13
# 4  0.2879  0.75        0.0       0           1    1

# %%
import pandas as pd
data = pd.concat([data,data2], axis=0)

# %%
data.shape
# Out:
# (27379, 15)

# %%
from pycaret.regression import *

# %%
s = setup(data, target='registered', session_id=786)
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_2c0401ae_37c8_11ea_8f82_84fdd13f47d7" ><thead>    <tr>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_2c0401ae_37c8_11ea_8f82_84fdd13f47d7row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_2c0401ae_37c8_11ea_8f82_84fdd13f47d7row0_col1" class="data row0 col1" >786</td>
#             </tr>
#             <tr>
#                                 <td id="T_2c0401ae_37c8_11ea_8f82_84fdd13f47d7row1_col0" class="data row1 col0" >Original Data</td>
#                         <td id="T_2c0401ae_37c8_11ea_8f82_84fdd13f47d7row1_col1" class="data row1 col1" >(27379, 14)</td>
#             </tr>
#             <tr>
# ...

# %%
# %%time
compare_models(blacklist=['tr','svm'])
# Out:
# Wall time: 2min 43s
# <style  type="text/css" >
#     #T_8e009f48_37c8_11ea_8e18_84fdd13f47d7 th {
#           text-align: left;
#     }    #T_8e009f48_37c8_11ea_8e18_84fdd13f47d7row0_col0 {
#             text-align:  left;
#         }    #T_8e009f48_37c8_11ea_8e18_84fdd13f47d7row0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_8e009f48_37c8_11ea_8e18_84fdd13f47d7row0_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_8e009f48_37c8_11ea_8e18_84fdd13f47d7row0_col3 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_8e009f48_37c8_11ea_8e18_84fdd13f47d7row0_col4 {
#             text-align:  left;
#         }    #T_8e009f48_37c8_11ea_8e18_84fdd13f47d7row0_col5 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_8e009f48_37c8_11ea_8e18_84fdd13f47d7row1_col0 {
#             text-align:  left;
# ...
