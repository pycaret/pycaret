# %%
from pycaret.datasets import get_data
data = get_data('france')
# Out:
#   InvoiceNo StockCode                      Description  Quantity  \
# 0    536370     22728        ALARM CLOCK BAKELIKE PINK        24
# 1    536370     22727        ALARM CLOCK BAKELIKE RED         24
# 2    536370     22726       ALARM CLOCK BAKELIKE GREEN        12
# 3    536370     21724  PANDA AND BUNNIES STICKER SHEET        12
# 4    536370     21883                 STARS GIFT TAPE         24
#
#       InvoiceDate  UnitPrice  CustomerID Country
# 0  12/1/2010 8:45       3.75     12583.0  France
# 1  12/1/2010 8:45       3.75     12583.0  France
# 2  12/1/2010 8:45       3.75     12583.0  France
# 3  12/1/2010 8:45       0.85     12583.0  France
# 4  12/1/2010 8:45       0.65     12583.0  France

# %%
from pycaret.arules import *

# %%
s = setup(data, transaction_id = 'InvoiceNo', item_id = 'Description', ignore_items = 'POSTAGE')
# Out:
# <style  type="text/css" >
# </style><table id="T_412ddf90_37d1_11ea_804c_84fdd13f47d7" ><thead>    <tr>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_412ddf90_37d1_11ea_804c_84fdd13f47d7row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_412ddf90_37d1_11ea_804c_84fdd13f47d7row0_col1" class="data row0 col1" >2789</td>
#             </tr>
#             <tr>
#                                 <td id="T_412ddf90_37d1_11ea_804c_84fdd13f47d7row1_col0" class="data row1 col0" ># Transactions</td>
#                         <td id="T_412ddf90_37d1_11ea_804c_84fdd13f47d7row1_col1" class="data row1 col1" >461</td>
#             </tr>
#             <tr>
#                                 <td id="T_412ddf90_37d1_11ea_804c_84fdd13f47d7row2_col0" class="data row2 col0" ># Items</td>
# ...

# %%
model1 = create_model()

# %%
plot_model(model1)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="e0b630ef-0800-4d27-bb93-ff435c1f6cf6" class="plotly-graph-div" style="height:800px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e0b630ef-0800-4d27-bb93-ff435c1f6cf6")) {
#                     Plotly.newPlot(
# ...

# %%
plot_model(model1, plot='3d')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="d7d68e21-6f10-4c77-ba98-4dd8a57d743a" class="plotly-graph-div" style="height:800px; width:900px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d7d68e21-6f10-4c77-ba98-4dd8a57d743a")) {
#                     Plotly.newPlot(
# ...
