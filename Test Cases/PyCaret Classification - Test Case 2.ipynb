# %%
from pycaret.datasets import get_data
data = get_data('income')
# Out:
#    age          workclass   education   education-num       marital-status  \
# 0   39          State-gov   Bachelors              13        Never-married
# 1   50   Self-emp-not-inc   Bachelors              13   Married-civ-spouse
# 2   38            Private     HS-grad               9             Divorced
# 3   53            Private        11th               7   Married-civ-spouse
# 4   28            Private   Bachelors              13   Married-civ-spouse
#
#            occupation    relationship    race      sex   capital-gain  \
# 0        Adm-clerical   Not-in-family   White     Male           2174
# 1     Exec-managerial         Husband   White     Male              0
# 2   Handlers-cleaners   Not-in-family   White     Male              0
# 3   Handlers-cleaners         Husband   Black     Male              0
# 4      Prof-specialty            Wife   Black   Female              0
#
#     capital-loss   hours-per-week  native-country  income >50K
# ...

# %%
import pandas as pd
data = pd.get_dummies(data)
data.head()
# Out:
#    age   education-num   capital-gain   capital-loss   hours-per-week  \
# 0   39              13           2174              0               40
# 1   50              13              0              0               13
# 2   38               9              0              0               40
# 3   53               7              0              0               40
# 4   28              13              0              0               40
#
#    income >50K   workclass_ Federal-gov   workclass_ Local-gov  \
# 0            0                        0                      0
# 1            0                        0                      0
# 2            0                        0                      0
# 3            0                        0                      0
# 4            0                        0                      0
#
#     workclass_ Never-worked   workclass_ Private  ...  \
# 0                         0                    0  ...
# ...

# %%
from pycaret.classification import *

# %%
s = setup(data, target='income >50K', session_id=786)
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_cfa1c2b4_37b5_11ea_8c4f_84fdd13f47d7" ><thead>    <tr>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_cfa1c2b4_37b5_11ea_8c4f_84fdd13f47d7row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_cfa1c2b4_37b5_11ea_8c4f_84fdd13f47d7row0_col1" class="data row0 col1" >786</td>
#             </tr>
#             <tr>
#                                 <td id="T_cfa1c2b4_37b5_11ea_8c4f_84fdd13f47d7row1_col0" class="data row1 col0" >Target Type</td>
#                         <td id="T_cfa1c2b4_37b5_11ea_8c4f_84fdd13f47d7row1_col1" class="data row1 col1" >Binary</td>
#             </tr>
#             <tr>
# ...

# %% [markdown]
# ## Compare Models

# %%
# %%time
compare_models()
# Out:
# Wall time: 5min 27s
# <style  type="text/css" >
#     #T_9c66e90a_37b6_11ea_938b_84fdd13f47d7 th {
#           text-align: left;
#     }    #T_9c66e90a_37b6_11ea_938b_84fdd13f47d7row0_col0 {
#             text-align:  left;
#         }    #T_9c66e90a_37b6_11ea_938b_84fdd13f47d7row0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_9c66e90a_37b6_11ea_938b_84fdd13f47d7row0_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_9c66e90a_37b6_11ea_938b_84fdd13f47d7row0_col3 {
#             : ;
#             text-align:  left;
#         }    #T_9c66e90a_37b6_11ea_938b_84fdd13f47d7row0_col4 {
#             : ;
#             text-align:  left;
#         }    #T_9c66e90a_37b6_11ea_938b_84fdd13f47d7row0_col5 {
#             : ;
#             text-align:  left;
#         }    #T_9c66e90a_37b6_11ea_938b_84fdd13f47d7row0_col6 {
#             background-color:  yellow;
#             text-align:  left;
# ...

# %% [markdown]
# ## Blend Models

# %%
# %%time
b1 = blend_models()
# Out:
#       Accuracy  AUC  Recall   Prec.      F1   Kappa
# 0       0.8645  0.0  0.5701  0.8109  0.6695  0.5875
# 1       0.8697  0.0  0.5938  0.8150  0.6870  0.6073
# 2       0.8640  0.0  0.5993  0.7852  0.6798  0.5954
# 3       0.8666  0.0  0.5974  0.7981  0.6833  0.6010
# 4       0.8706  0.0  0.5920  0.8207  0.6878  0.6089
# 5       0.8662  0.0  0.6066  0.7891  0.6859  0.6027
# 6       0.8692  0.0  0.6011  0.8068  0.6889  0.6084
# 7       0.8499  0.0  0.5410  0.7674  0.6346  0.5437
# 8       0.8578  0.0  0.5774  0.7751  0.6618  0.5742
# 9       0.8670  0.0  0.5912  0.8040  0.6814  0.5998
# Mean    0.8646  0.0  0.5870  0.7972  0.6760  0.5929
# SD      0.0060  0.0  0.0185  0.0167  0.0161  0.0193
# Wall time: 2min 57s
