# %%
from pycaret.datasets import get_data
get_data('index')
# Out:
#           Dataset    Data Types               Default Task  \
# 0          cancer  Multivariate             Classification
# 1          credit  Multivariate             Classification
# 2        employee  Multivariate             Classification
# 3           heart  Multivariate             Classification
# 4       hepatitis  Multivariate             Classification
# 5          income  Multivariate             Classification
# 6            iris  Multivariate             Classification
# 7           juice  Multivariate             Classification
# 8   heart_disease  Multivariate             Classification
# 9           glass  Multivariate  Multiclass Classification
# 10      satellite  Multivariate  Multiclass Classification
# 11          poker  Multivariate  Multiclass Classification
# 12     automobile  Multivariate                 Regression
# 13           bike  Multivariate                 Regression
# 14         boston  Multivariate                 Regression
# ...

# %%
data = get_data('kiva')
data = data.head(1500)
# Out:
#               country                                                 en  \
# 0  Dominican Republic  "Banco Esperanza" is a group of 10 women looki...
# 1  Dominican Republic  "Caminemos Hacia Adelante" or "Walking Forward...
# 2  Dominican Republic  "Creciendo Por La Union" is a group of 10 peop...
# 3  Dominican Republic  "Cristo Vive" ("Christ lives" is a group of 10...
# 4  Dominican Republic  "Cristo Vive" is a large group of 35 people, 2...
#
#   gender  loan_amount nonpayment    sector  status
# 0      F         1225    partner    Retail       0
# 1      F         1975     lender  Clothing       0
# 2      F         2175    partner  Clothing       0
# 3      F         1425    partner  Clothing       0
# 4      F         4025    partner      Food       0

# %%
from pycaret.nlp import *

# %%
s = setup(data, target='en')
# Out:
# <style  type="text/css" >
# </style><table id="T_7c1a9bfa_3283_11ea_b204_84fdd13f47d7" ><thead>    <tr>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_7c1a9bfa_3283_11ea_b204_84fdd13f47d7row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_7c1a9bfa_3283_11ea_b204_84fdd13f47d7row0_col1" class="data row0 col1" >8937</td>
#             </tr>
#             <tr>
#                                 <td id="T_7c1a9bfa_3283_11ea_b204_84fdd13f47d7row1_col0" class="data row1 col0" ># Documents</td>
#                         <td id="T_7c1a9bfa_3283_11ea_b204_84fdd13f47d7row1_col1" class="data row1 col1" >1500</td>
#             </tr>
#             <tr>
#                                 <td id="T_7c1a9bfa_3283_11ea_b204_84fdd13f47d7row2_col0" class="data row2 col0" >Vocab Size</td>
# ...

# %%
lda = create_model(model='lda', multi_core=True)

# %%
lda

# %%
assign_model(lda)
# Out:
#                  country                                                 en  \
# 0     Dominican Republic  woman look receive small loan take small loan ...
# 1     Dominican Republic  caminemos walk forward group entrepreneur seek...
# 2     Dominican Republic  group people hope start business group look re...
# 3     Dominican Republic  live group woman look receive first loan young...
# 4     Dominican Republic  vive large group people hope take loan many se...
# ...                  ...                                                ...
# 1495  Dominican Republic  year old mother son attend school start busine...
# 1496  Dominican Republic  coordinator entrepreneur friend take second lo...
# 1497  Dominican Republic  start sell snack push street able open permane...
# 1498  Dominican Republic  woman live husband child age small community c...
# 1499  Dominican Republic  make bread year say main difficulty buy flour ...
#
# ...

# %%
plot_model(lda, plot='topic_distribution')
# Out:
# <div>
#
#
#             <div id="dae6d2d5-06a2-4da5-bfc8-c3b431830ab7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("dae6d2d5-06a2-4da5-bfc8-c3b431830ab7")) {
#                     Plotly.newPlot(
#                         'dae6d2d5-06a2-4da5-bfc8-c3b431830ab7',
# ...

# %%
plot_model(lda, plot='tsne' )
# Out:
# <div>
#
#
#             <div id="572dba9e-a7a7-4ffb-ac7b-b98144e0be94" class="plotly-graph-div" style="height:800px; width:900px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("572dba9e-a7a7-4ffb-ac7b-b98144e0be94")) {
#                     Plotly.newPlot(
#                         '572dba9e-a7a7-4ffb-ac7b-b98144e0be94',
# ...

# %%
nmf = create_model('nmf')

# %%
plot_model(nmf, plot='tsne')
# Out:
# <div>
#
#
#             <div id="e07f09b8-f079-4786-b17e-7135bd7c798f" class="plotly-graph-div" style="height:800px; width:900px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e07f09b8-f079-4786-b17e-7135bd7c798f")) {
#                     Plotly.newPlot(
#                         'e07f09b8-f079-4786-b17e-7135bd7c798f',
# ...

# %%
assign_model(lda)
# Out:
#                  country                                                 en  \
# 0     Dominican Republic  woman look receive small loan take small loan ...
# 1     Dominican Republic  caminemos walk forward group entrepreneur seek...
# 2     Dominican Republic  group people hope start business group look re...
# 3     Dominican Republic  live group woman look receive first loan young...
# 4     Dominican Republic  vive large group people hope take loan many se...
# ...                  ...                                                ...
# 1495  Dominican Republic  year old mother son attend school start busine...
# 1496  Dominican Republic  coordinator entrepreneur friend take second lo...
# 1497  Dominican Republic  start sell snack push street able open permane...
# 1498  Dominican Republic  woman live husband child age small community c...
# 1499  Dominican Republic  make bread year say main difficulty buy flour ...
#
# ...

# %%
plot_model(lda, plot='bigram')
# Out:
# <div>
#
#
#             <div id="72428710-6889-4f78-9065-691a09e7a08c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("72428710-6889-4f78-9065-691a09e7a08c")) {
#                     Plotly.newPlot(
#                         '72428710-6889-4f78-9065-691a09e7a08c',
# ...

# %%
plot_model(lda, plot='wordcloud')

# %%
plot_model(lda, plot='trigram')
# Out:
# <div>
#
#
#             <div id="02c24ce1-7d16-4036-9cf1-0bdc1a4b892f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("02c24ce1-7d16-4036-9cf1-0bdc1a4b892f")) {
#                     Plotly.newPlot(
#                         '02c24ce1-7d16-4036-9cf1-0bdc1a4b892f',
# ...

# %%
tuned_model = tune_model(model='lda', multi_core = True, supervised_target='status')
# Out:
# <div>
#
#
#             <div id="7957e7de-4064-4b13-8bf6-ed1547b5d0e2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7957e7de-4064-4b13-8bf6-ed1547b5d0e2")) {
#                     Plotly.newPlot(
#                         '7957e7de-4064-4b13-8bf6-ed1547b5d0e2',
# ...

# %%
assign_model(tuned_model)
# Out:
#                  country                                                 en  \
# 0     Dominican Republic  woman look receive small loan take small loan ...
# 1     Dominican Republic  caminemos walk forward group entrepreneur seek...
# 2     Dominican Republic  group people hope start business group look re...
# 3     Dominican Republic  live group woman look receive first loan young...
# 4     Dominican Republic  vive large group people hope take loan many se...
# ...                  ...                                                ...
# 1495  Dominican Republic  year old mother son attend school start busine...
# 1496  Dominican Republic  coordinator entrepreneur friend take second lo...
# 1497  Dominican Republic  start sell snack push street able open permane...
# 1498  Dominican Republic  woman live husband child age small community c...
# 1499  Dominican Republic  make bread year say main difficulty buy flour ...
#
# ...
